# %%
from metasyn.builder import MetaFrameBuilder, VarBuilder
from metasyn.privacy import BasicPrivacy
from metasyn.distribution import NADistribution, DiscreteUniformDistribution, StringConstantDistribution, ContinuousUniformDistribution, RegexDistribution
from metasyn.distribution.base import ColumnReference, IfThenElse
from metasyn import demo_data
from metasyncontrib.disclosure.privacy import DisclosurePrivacy

# %%
df = demo_data("titanic")
builder = MetaFrameBuilder()
builder.add_dataframe(df, None)
builder["PassengerId"].distribution = {"unique": True}
# builder["PassengerId"].distribution = ColumnReference("base")
builder["Fare"].distribution = {"name": "uniform"}
builder["Fare"].distribution = ContinuousUniformDistribution(lower=0.1, upper=0.2)
builder["Fare"].distribution = ContinuousUniformDistribution
builder["Fare"].distribution = None

builder["Fare"].privacy = BasicPrivacy()
builder.privacy = BasicPrivacy()
builder.preview()
builder["Age"].distribution = IfThenElse(ColumnReference("Sex") == StringConstantDistribution("male"), NADistribution(), DiscreteUniformDistribution(20, 40))
builder["Fare"].distribution = ColumnReference("Age")
# builder["Sex"].distribution = ColumnReference("Name") + RegexDistribution(" (M|F)")

# %%
# builder = MultiFrameBuilder()
# builder["tabel1"]["PassengerId"].distribution = {"unique": True}
# builder["Fare"].distribution = ColumnRelation("Age") + 10 + ContinuousUniformDistribution(1.0, 0.0)

# %%
mf = builder.fit()
# Out:
# 100%|██████████| 13/13 [00:02<00:00,  5.15it/s]

# %%
mf.synthesize(10)
# Out:
#  PassengerId: 100%|██████████| 13/13 [00:00<00:00, 367.63variables/s]
# shape: (10, 13)
# ┌─────────────┬──────────────┬────────┬──────┬───┬────────────┬────────────┬──────────────┬────────┐
# │ PassengerId ┆ Name         ┆ Sex    ┆ Age  ┆ … ┆ Birthday   ┆ Board time ┆ Married      ┆ all_NA │
# │ ---         ┆ ---          ┆ ---    ┆ ---  ┆   ┆ ---        ┆ ---        ┆ since        ┆ ---    │
# │ i64         ┆ str          ┆ cat    ┆ i64  ┆   ┆ date       ┆ time       ┆ ---          ┆ str    │
# │             ┆              ┆        ┆      ┆   ┆            ┆            ┆ datetime[μs] ┆        │
# ╞═════════════╪══════════════╪════════╪══════╪═══╪════════════╪════════════╪══════════════╪════════╡
# │ 1           ┆ Tend card.   ┆ male   ┆ null ┆ … ┆ 1930-02-10 ┆ 17:52:33   ┆ 2022-07-29   ┆ null   │
# │             ┆ Whose sing.  ┆        ┆      ┆   ┆            ┆            ┆ 15:28:10     ┆        │
# │ 2           ┆ Trip.        ┆ male   ┆ null ┆ … ┆ 1926-11-28 ┆ 14:49:49   ┆ 2022-08-09   ┆ null   │
# │             ┆ Notice.      ┆        ┆      ┆   ┆            ┆            ┆ 21:36:22     ┆        │
# │             ┆ Student.     ┆        ┆      ┆   ┆            ┆            ┆              ┆        │
# │             ┆ Approac…     ┆        ┆      ┆   ┆            ┆            ┆              ┆        │
# │ 3           ┆ Scientist.   ┆ male   ┆ null ┆ … ┆ 1930-08-14 ┆ 13:38:51   ┆ 2022-07-31   ┆ null   │
# │             ┆              ┆        ┆      ┆   ┆            ┆            ┆ 15:16:16     ┆        │
# │ 4           ┆ Month.       ┆ male   ┆ null ┆ … ┆ 1910-03-20 ┆ 17:16:40   ┆ 2022-08-11   ┆ null   │
# │             ┆ Conference.  ┆        ┆      ┆   ┆            ┆            ┆ 19:48:26     ┆        │
# │             ┆ Interesting… ┆        ┆      ┆   ┆            ┆            ┆              ┆        │
# │ 5           ┆ Recognize.   ┆ male   ┆ null ┆ … ┆ 1935-09-01 ┆ 17:39:42   ┆ 2022-07-24   ┆ null   │
# │             ┆ Mr. Save.    ┆        ┆      ┆   ┆            ┆            ┆ 13:37:09     ┆        │
# │ 6           ┆ Such thus    ┆ male   ┆ null ┆ … ┆ 1911-09-27 ┆ 17:15:07   ┆ 2022-07-29   ┆ null   │
# │             ┆ maintain.    ┆        ┆      ┆   ┆            ┆            ┆ 10:36:20     ┆        │
# │ 7           ┆ Green. Hot.  ┆ male   ┆ null ┆ … ┆ 1914-08-20 ┆ 12:22:23   ┆ 2022-07-30   ┆ null   │
# │             ┆              ┆        ┆      ┆   ┆            ┆            ┆ 18:02:46     ┆        │
# │ 8           ┆ Program.     ┆ male   ┆ null ┆ … ┆ 1905-08-01 ┆ 18:39:10   ┆ 2022-08-03   ┆ null   │
# │             ┆ Pattern.     ┆        ┆      ┆   ┆            ┆            ┆ 20:26:00     ┆        │
# │ 9           ┆ Cell just.   ┆ male   ┆ null ┆ … ┆ 1904-08-16 ┆ 10:40:00   ┆ 2022-08-08   ┆ null   │
# │             ┆ Treatment    ┆        ┆      ┆   ┆            ┆            ┆ 09:07:05     ┆        │
# │             ┆ send.        ┆        ┆      ┆   ┆            ┆            ┆              ┆        │
# │ 10          ┆ Probably.    ┆ female ┆ 21   ┆ … ┆ 1914-10-17 ┆ 16:53:21   ┆ 2022-07-29   ┆ null   │
# │             ┆ Most.        ┆        ┆      ┆   ┆            ┆            ┆ 12:16:14     ┆        │
# └─────────────┴──────────────┴────────┴──────┴───┴────────────┴────────────┴──────────────┴────────┘
